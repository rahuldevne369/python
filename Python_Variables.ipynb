# %%
x=5
y=1
a="rahul"
print(x,y,a)
# Out:
# 5 1 rahul

# %%
b=str(a)
print(b)
# Out:
# rahul

# %%
print(type(x))
print(type(y))
print(type(a))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'str'>

# %%
a=4
a="rama"
print(a)
# Out:
# rama

# %%
a=4
A="ram"
print(a)
# Out:
# 4

# %%
class = 10 
print(class)
# Out:
#   Cell In[17], line 1
#     class = 10
#           ^
# SyntaxError: invalid syntax

# %%
s="10"
n=int(s)
print(type(n))
# Out:
# <class 'int'>

# %% [markdown]
# Global and Local Variables in Python

# %%
def greet():
    msg="hello"
    print(msg)

greet()
# Out:
# hello

# %%
def greet():
    msg="hello"
    print("hi rahul",msg)

greet()
print("outside",msg)
# Out:
# hi rahul hello
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 6
#       3     print("hi rahul",msg)
#       5 greet()
# ----> 6 print("outside",msg)
#
# NameError: name 'msg' is not defined

# %% [markdown]
# Global variables are declared outside all functions and can be accessed anywhere in the program, including inside functions.

# %%
msg="hello how are you?"

def greet():
    msg="hello"
    print("(inside)hi rahul",msg)

greet()
print("outside",msg)
# Out:
# (inside)hi rahul hello
# outside hello how are you?
